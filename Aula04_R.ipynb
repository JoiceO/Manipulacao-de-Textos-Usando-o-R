# %%
install.packages("stringr")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(stringr)

# %%
fruit
# Out:
#  [1] "apple"             "apricot"           "avocado"
#  [4] "banana"            "bell pepper"       "bilberry"
#  [7] "blackberry"        "blackcurrant"      "blood orange"
# [10] "blueberry"         "boysenberry"       "breadfruit"
# [13] "canary melon"      "cantaloupe"        "cherimoya"
# [16] "cherry"            "chili pepper"      "clementine"
# [19] "cloudberry"        "coconut"           "cranberry"
# [22] "cucumber"          "currant"           "damson"
# [25] "date"              "dragonfruit"       "durian"
# [28] "eggplant"          "elderberry"        "feijoa"
# [31] "fig"               "goji berry"        "gooseberry"
# [34] "grape"             "grapefruit"        "guava"
# [37] "honeydew"          "huckleberry"       "jackfruit"
# [40] "jambul"            "jujube"            "kiwi fruit"
# [43] "kumquat"           "lemon"             "lime"
# [46] "loquat"            "lychee"            "mandarine"
# [49] "mango"             "mulberry"          "nectarine"
# ...

# %%
str_detect(fruit,"a") #detecta se o objeto tem ou não a letra 'a'
# Out:
#  [1]  TRUE  TRUE  TRUE  TRUE FALSE FALSE  TRUE  TRUE  TRUE FALSE FALSE  TRUE
# [13]  TRUE  TRUE  TRUE FALSE FALSE FALSE FALSE FALSE  TRUE FALSE  TRUE  TRUE
# [25]  TRUE  TRUE  TRUE  TRUE FALSE  TRUE FALSE FALSE FALSE  TRUE  TRUE  TRUE
# [37] FALSE FALSE  TRUE  TRUE FALSE FALSE  TRUE FALSE FALSE  TRUE FALSE  TRUE
# [49]  TRUE FALSE  TRUE FALSE FALSE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE FALSE
# [61]  TRUE  TRUE FALSE  TRUE FALSE  TRUE FALSE  TRUE  TRUE  TRUE  TRUE FALSE
# [73]  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE FALSE  TRUE

# %%
str_which(fruit,"a") #retorna a posição no vetor do objeto que tem 'a'
# Out:
#  [1]  1  2  3  4  7  8  9 12 13 14 15 21 23 24 25 26 27 28 30 34 35 36 39 40 43
# [26] 46 48 49 51 54 55 56 57 58 59 61 62 64 66 68 69 70 71 73 74 75 76 77 78 80

# %%
str_count(fruit,"a") #mostra quantas vezes cada objeto tem a letra 'a'
# Out:
#  [1] 1 1 2 3 0 0 1 2 1 0 0 1 2 2 1 0 0 0 0 0 1 0 1 1 1 1 1 1 0 1 0 0 0 1 1 2 0 0
# [39] 1 1 0 0 1 0 0 1 0 2 1 0 1 0 0 1 1 3 1 1 1 0 1 1 0 2 0 1 0 1 2 1 1 0 2 2 1 1
# [77] 2 1 0 1

# %%
str_locate(fruit,"a") #localiza a posuição da letra 'a' em cada objeto
# Out:
#       start end
#  [1,]  1     1
#  [2,]  1     1
#  [3,]  1     1
#  [4,]  2     2
#  [5,] NA    NA
#  [6,] NA    NA
#  [7,]  3     3
#  [8,]  3     3
#  [9,]  9     9
# [10,] NA    NA
# [11,] NA    NA
# [12,]  4     4
# [13,]  2     2
# [14,]  2     2
# [15,]  9     9
# [16,] NA    NA
# [17,] NA    NA
# [18,] NA    NA
# [19,] NA    NA
# [20,] NA    NA
# [21,]  3     3
# [22,] NA    NA
# [23,]  5     5
# [24,]  2     2
# [25,]  2     2
# [26,]  3     3
# [27,]  5     5
# [28,]  6     6
# [29,] NA    NA
# [30,]  6     6
# [31,] ⋮     ⋮
# [32,]  5     5
# [33,] NA    NA
# [34,] NA    NA
# [35,]  3     3
# [36,]  2     2
# [37,]  2     2
# [38,]  2     2
# [39,]  3     3
# [40,]  3     3
# [41,] NA    NA
# [42,]  5     5
# [43,]  5     5
# [44,] NA    NA
# [45,]  7     7
# [46,] NA    NA
# [47,]  9     9
# [48,] NA    NA
# [49,]  2     2
# [50,]  2     2
# [51,]  2     2
# [52,]  8     8
# [53,] NA    NA
# [54,]  2     2
# [55,]  2     2
# [56,]  3     3
# [57,]  4     4
# ...

# %%
str_locate_all(fruit,"a")
# Out:
# [[1]]
#      start end
# [1,]     1   1
#
# [[2]]
#      start end
# [1,]     1   1
#
# [[3]]
#      start end
# [1,]     1   1
# [2,]     5   5
#
# [[4]]
#      start end
# [1,]     2   2
# [2,]     4   4
# [3,]     6   6
#
# [[5]]
#      start end
#
# [[6]]
#      start end
#
# [[7]]
#      start end
# [1,]     3   3
#
# [[8]]
#      start end
# [1,]     3   3
# [2,]    10  10
#
# [[9]]
#      start end
# [1,]     9   9
#
# [[10]]
#      start end
#
# [[11]]
#      start end
#
# [[12]]
#      start end
# [1,]     4   4
#
# [[13]]
#      start end
# [1,]     2   2
# [2,]     4   4
#
# [[14]]
#      start end
# [1,]     2   2
# [2,]     5   5
#
# [[15]]
#      start end
# [1,]     9   9
#
# [[16]]
#      start end
#
# [[17]]
#      start end
#
# [[18]]
#      start end
#
# [[19]]
#      start end
#
# [[20]]
#      start end
#
# [[21]]
#      start end
# [1,]     3   3
#
# [[22]]
#      start end
#
# [[23]]
#      start end
# [1,]     5   5
#
# [[24]]
#      start end
# ...

# %%
str_sub(fruit,1,3) #separa as 3 primeiras palavras de cada objeto
# Out:
#  [1] "app" "apr" "avo" "ban" "bel" "bil" "bla" "bla" "blo" "blu" "boy" "bre"
# [13] "can" "can" "che" "che" "chi" "cle" "clo" "coc" "cra" "cuc" "cur" "dam"
# [25] "dat" "dra" "dur" "egg" "eld" "fei" "fig" "goj" "goo" "gra" "gra" "gua"
# [37] "hon" "huc" "jac" "jam" "juj" "kiw" "kum" "lem" "lim" "loq" "lyc" "man"
# [49] "man" "mul" "nec" "nut" "oli" "ora" "pam" "pap" "pas" "pea" "pea" "per"
# [61] "phy" "pin" "plu" "pom" "pom" "pur" "qui" "rai" "ram" "ras" "red" "roc"
# [73] "sal" "sat" "sta" "str" "tam" "tan" "ugl" "wat"

# %%
str_sub(fruit,-3) #separa as 3 últimas palavras de cada objeto
# Out:
#  [1] "ple" "cot" "ado" "ana" "per" "rry" "rry" "ant" "nge" "rry" "rry" "uit"
# [13] "lon" "upe" "oya" "rry" "per" "ine" "rry" "nut" "rry" "ber" "ant" "son"
# [25] "ate" "uit" "ian" "ant" "rry" "joa" "fig" "rry" "rry" "ape" "uit" "ava"
# [37] "dew" "rry" "uit" "bul" "ube" "uit" "uat" "mon" "ime" "uat" "hee" "ine"
# [49] "ngo" "rry" "ine" "nut" "ive" "nge" "elo" "aya" "uit" "ach" "ear" "mon"
# [61] "lis" "ple" "lum" "ate" "elo" "een" "nce" "sin" "tan" "rry" "ant" "lon"
# [73] "rry" "uma" "uit" "rry" "llo" "ine" "uit" "lon"

# %%
str_subset(fruit,"b") #cria um subvetor com os objetos que tem a letra 'b'
# Out:
#  [1] "banana"       "bell pepper"  "bilberry"     "blackberry"   "blackcurrant"
#  [6] "blood orange" "blueberry"    "boysenberry"  "breadfruit"   "cloudberry"
# [11] "cranberry"    "cucumber"     "elderberry"   "goji berry"   "gooseberry"
# [16] "huckleberry"  "jambul"       "jujube"       "mulberry"     "rambutan"
# [21] "raspberry"    "salal berry"  "strawberry"

# %%
grep("b", fruit, value = TRUE) #função grep faz o mesmo que a função acima
# Out:
#  [1] "banana"       "bell pepper"  "bilberry"     "blackberry"   "blackcurrant"
#  [6] "blood orange" "blueberry"    "boysenberry"  "breadfruit"   "cloudberry"
# [11] "cranberry"    "cucumber"     "elderberry"   "goji berry"   "gooseberry"
# [16] "huckleberry"  "jambul"       "jujube"       "mulberry"     "rambutan"
# [21] "raspberry"    "salal berry"  "strawberry"

# %%
str_extract(fruit,"[aeiou]")
# Out:
#  [1] "a" "a" "a" "a" "e" "i" "a" "a" "o" "u" "o" "e" "a" "a" "e" "e" "i" "e" "o"
# [20] "o" "a" "u" "u" "a" "a" "a" "u" "e" "e" "e" "i" "o" "o" "a" "a" "u" "o" "u"
# [39] "a" "a" "u" "i" "u" "e" "i" "o" "e" "a" "a" "u" "e" "u" "o" "o" "a" "a" "a"
# [58] "e" "e" "e" "a" "i" "u" "o" "o" "u" "u" "a" "a" "a" "e" "o" "a" "a" "a" "a"
# [77] "a" "a" "u" "a"

# %%
sentences
# Out:
#   [1] "The birch canoe slid on the smooth planks."
#   [2] "Glue the sheet to the dark blue background."
#   [3] "It's easy to tell the depth of a well."
#   [4] "These days a chicken leg is a rare dish."
#   [5] "Rice is often served in round bowls."
#   [6] "The juice of lemons makes fine punch."
#   [7] "The box was thrown beside the parked truck."
#   [8] "The hogs were fed chopped corn and garbage."
#   [9] "Four hours of steady work faced us."
#  [10] "Large size in stockings is hard to sell."
#  [11] "The boy was there when the sun rose."
#  [12] "A rod is used to catch pink salmon."
#  [13] "The source of the huge river is the clear spring."
#  [14] "Kick the ball straight and follow through."
#  [15] "Help the woman get back to her feet."
#  [16] "A pot of tea helps to pass the evening."
#  [17] "Smoky fires lack flame and heat."
#  [18] "The soft cushion broke the man's fall."
#  [19] "The salt breeze came across from the sea."
# ...

# %%
str_match(sentences,"(a|the) (\\w+)")
# Out:
#       [,1]         [,2] [,3]
#  [1,] the smooth   the  smooth
#  [2,] the sheet    the  sheet
#  [3,] the depth    the  depth
#  [4,] a chicken    a    chicken
#  [5,] NA           NA   NA
#  [6,] NA           NA   NA
#  [7,] the parked   the  parked
#  [8,] NA           NA   NA
#  [9,] NA           NA   NA
# [10,] NA           NA   NA
# [11,] the sun      the  sun
# [12,] NA           NA   NA
# [13,] the huge     the  huge
# [14,] the ball     the  ball
# [15,] the woman    the  woman
# [16,] a helps      a    helps
# [17,] NA           NA   NA
# [18,] the man      the  man
# [19,] the sea      the  sea
# [20,] the booth    the  booth
# [21,] a hole       a    hole
# [22,] the bent     the  bent
# [23,] the pants    the  pants
# [24,] NA           NA   NA
# [25,] the view     the  view
# [26,] the tank     the  tank
# [27,] NA           NA   NA
# [28,] the tall     the  tall
# [29,] the same     the  same
# [30,] NA           NA   NA
# [31,] ⋮            ⋮    ⋮
# ...

# %%
str_length(fruit)
# Out:
#  [1]  5  7  7  6 11  8 10 12 12  9 11 10 12 10  9  6 12 10 10  7  9  8  7  6  4
# [26] 11  6  8 10  6  3 10 10  5 10  5  8 11  9  6  6 10  7  5  4  6  6  9  5  8
# [51]  9  3  5  6  6  6 12  5  4  9  8  9  4 11  6 17  6  6  8  9 10 10 11  7 10
# [76] 10  9  9 10 10

# %%
length(fruit)
# Out:
# [1] 80

# %% [markdown]
# #Exercícios
# Utilize o conjunto de dados `fruit` em todos os exercícios <br>
# 1. Verifique, utlizando a função `str_which()`, se existe alguma fruta no vetor que não contém nenhuma vogal.

# %%
fruit[-str_which(fruit, "[aeiou]")]
# Out:
# character(0)

# %% [markdown]
# 2. Usando apenas uma linha de comando, execute um código que retorna a quantidade de frutas que possuem nome composto

# %%
length(str_which(fruit, "\\s"))
# Out:
# [1] 11

# %% [markdown]
# 3. Utilizando apenas uma linha de comando, execute um código que retorna a quantidade de frutas que possuem a letra 'a' como segunda letra do nome.

# %%
fruit[grep(".a." , str_sub(fruit, 1, 3))]
# Out:
#  [1] "banana"       "canary melon" "cantaloupe"   "damson"       "date"
#  [6] "jackfruit"    "jambul"       "mandarine"    "mango"        "pamelo"
# [11] "papaya"       "passionfruit" "raisin"       "rambutan"     "raspberry"
# [16] "salal berry"  "satsuma"      "tamarillo"    "tangerine"    "watermelon"

# %% [markdown]
# 4. Armazene o nome das frutas do exercício anterior em um novo vetor chamado `vet_a2`

# %%
vet_a2 = fruit[grep(".a." , str_sub(fruit, 1, 3))]
vet_a2
# Out:
#  [1] "banana"       "canary melon" "cantaloupe"   "damson"       "date"
#  [6] "jackfruit"    "jambul"       "mandarine"    "mango"        "pamelo"
# [11] "papaya"       "passionfruit" "raisin"       "rambutan"     "raspberry"
# [16] "salal berry"  "satsuma"      "tamarillo"    "tangerine"    "watermelon"

# %% [markdown]
# 5. Substitua somente a letra 'a' presente na segunda letra do nome das frutas por "-". (exemplo: "b-nana")

# %%
str_sub(vet_a2, 2, 2) = "-" 
vet_a2
# Out:
#  [1] "b-nana"       "c-nary melon" "c-ntaloupe"   "d-mson"       "d-te"
#  [6] "j-ckfruit"    "j-mbul"       "m-ndarine"    "m-ngo"        "p-melo"
# [11] "p-paya"       "p-ssionfruit" "r-isin"       "r-mbutan"     "r-spberry"
# [16] "s-lal berry"  "s-tsuma"      "t-marillo"    "t-ngerine"    "w-termelon"
